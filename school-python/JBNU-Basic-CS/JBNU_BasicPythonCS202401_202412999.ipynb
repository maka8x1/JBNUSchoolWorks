# %% [markdown]
# <small>*~~으아악 전대빌런이다 돔황챠~~*<small/> <br />
# <small>**당신 뭘 믿고 이런 짓 하는거야?**<small/>

# %% [markdown]
# # 2024-03-06

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print("Hello, Python Programming!")

print(52)
print(273)

print()

print("안녕하세요", "저의 이름은", "ㅁㄴㅇㄹ")
# Out:
# Hello, Python Programming!
# 52
# 273
#
# 안녕하세요 저의 이름은 ㅁㄴㅇㄹ

# %% [markdown]
# <br />

# %% [markdown]
# # 2024-03-11

# %%
floatvar = 3.14
print(type(floatvar))

print(type("안녕하세요"))

print(type(273))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'int'>

# %%
print("'안녕하세요'라고 말했습니다.")

print("\"안녕하세요\"라고 말했습니다.")

print("he said \'Hello\' to you.")

print("안녕하세요\t안녕하세요")
print("안녕하세요\n안녕하세요")
# Out:
# '안녕하세요'라고 말했습니다.
# "안녕하세요"라고 말했습니다.
# he said 'Hello' to you.
# 안녕하세요	안녕하세요
# 안녕하세요
# 안녕하세요

# %%
print("이름\t나이\t지역")
print("윤성로\t25\t강서구")
print("윤아린\t25\t강서구")
# Out:
# 이름	나이	지역
# 윤성로	25	강서구
# 윤아린	25	강서구

# %%
print("\\ \\ \\ \\\n\n")
print("""동해물과 백두산이 마르고 닳도록
하느님이 보우하사 우리나라 만세
무궁화 삼천리 화려강산
대한사람 대한으로 길이 보전하세\
""")
# Out:
# \ \ \ \
#
#
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세
# 무궁화 삼천리 화려강산
# 대한사람 대한으로 길이 보전하세

# %%
print("HELLO" + " " + "WORLD" + "!")
print("슈퍼 트위치 깍두기 메이커\n"*3)
# Out:
# HELLO WORLD!
# 슈퍼 트위치 깍두기 메이커
# 슈퍼 트위치 깍두기 메이커
# 슈퍼 트위치 깍두기 메이커

# %%
print("안녕하세요"[0])
print("안녕하세요"[1])
print("안녕하세요"[2])
print("안녕하세요"[3])
print("안녕하세요"[4])

print("안녕하세요"[-1])
print("안녕하세요"[-2])
print("안녕하세요"[-3])
print("안녕하세요"[-4])
print("안녕하세요"[-5])

print("안녕하세요"[1:4])
print("안녕하세요"[2:])
print("안녕하세요"[:3])
# Out:
# 안
# 녕
# 하
# 세
# 요
# 요
# 세
# 하
# 녕
# 안
# 녕하세
# 하세요
# 안녕하

# %%
hello = "안녕하세요"

print(hello[0:2])

wronghello = "안년하세요"
print(wronghello)
wronghello = list(wronghello)
wronghello[1] = '녕'
print("".join(wronghello))

print(len(hello))
# Out:
# 안녕
# 안년하세요
# 안녕하세요
# 5

# %% [markdown]
# <br />

# %% [markdown]
# # 2024-03-13

# %%
for i in range(1, 255):
  print(i, "\t", bin(i), "\t", oct(i), "\t", hex(i))
# Out:
# 1 	 0b1 	 0o1 	 0x1
# 2 	 0b10 	 0o2 	 0x2
# 3 	 0b11 	 0o3 	 0x3
# 4 	 0b100 	 0o4 	 0x4
# 5 	 0b101 	 0o5 	 0x5
# 6 	 0b110 	 0o6 	 0x6
# 7 	 0b111 	 0o7 	 0x7
# 8 	 0b1000 	 0o10 	 0x8
# 9 	 0b1001 	 0o11 	 0x9
# 10 	 0b1010 	 0o12 	 0xa
# 11 	 0b1011 	 0o13 	 0xb
# 12 	 0b1100 	 0o14 	 0xc
# 13 	 0b1101 	 0o15 	 0xd
# 14 	 0b1110 	 0o16 	 0xe
# 15 	 0b1111 	 0o17 	 0xf
# 16 	 0b10000 	 0o20 	 0x10
# 17 	 0b10001 	 0o21 	 0x11
# 18 	 0b10010 	 0o22 	 0x12
# 19 	 0b10011 	 0o23 	 0x13
# 20 	 0b10100 	 0o24 	 0x14
# 21 	 0b10101 	 0o25 	 0x15
# 22 	 0b10110 	 0o26 	 0x16
# 23 	 0b10111 	 0o27 	 0x17
# 24 	 0b11000 	 0o30 	 0x18
# 25 	 0b11001 	 0o31 	 0x19
# 26 	 0b11010 	 0o32 	 0x1a
# 27 	 0b11011 	 0o33 	 0x1b
# 28 	 0b11100 	 0o34 	 0x1c
# 29 	 0b11101 	 0o35 	 0x1d
# 30 	 0b11110 	 0o36 	 0x1e
# 31 	 0b11111 	 0o37 	 0x1f
# 32 	 0b100000 	 0o40 	 0x20
# 33 	 0b100001 	 0o41 	 0x21
# 34 	 0b100010 	 0o42 	 0x22
# 35 	 0b100011 	 0o43 	 0x23
# 36 	 0b100100 	 0o44 	 0x24
# ...
